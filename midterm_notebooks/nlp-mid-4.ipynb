# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import requests

#download Shakespeare text
def download_text():
    url = "https://www.gutenberg.org/files/100/100-0.txt"
    response = requests.get(url)
    text = response.text
    start_index = text.find("THE SONNETS")
    end_index = text.find("THE END")
    return text[start_index:end_index]

dataset_text = download_text()

#tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts([dataset_text])
total_words = len(tokenizer.word_index) + 1

#convert text to sequences
input_sequences = []
for line in dataset_text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

max_sequence_length = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
model = Sequential([
    Embedding(total_words, 64),
    LSTM(150, activation = 'tanh', return_sequences=True),
    LSTM(150, activation = 'tanh', return_sequences=True),
    LSTM(150, activation = 'tanh'),
    Dense(total_words, activation='softmax')
])


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 39s 57ms/step - accuracy: 0.1075 - loss: 6.7849
# Epoch 2/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.1096 - loss: 6.2239
# Epoch 3/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - accuracy: 0.1175 - loss: 5.9553
# Epoch 4/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.1346 - loss: 5.7761
# Epoch 5/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 33s 60ms/step - accuracy: 0.1364 - loss: 5.6619
# Epoch 6/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 36s 65ms/step - accuracy: 0.1390 - loss: 5.5283
# Epoch 7/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 36s 66ms/step - accuracy: 0.1456 - loss: 5.3669
# Epoch 8/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 33s 59ms/step - accuracy: 0.1485 - loss: 5.2497
# Epoch 9/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.1545 - loss: 5.1228
# Epoch 10/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.1573 - loss: 5.0138
# Epoch 11/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - accuracy: 0.1623 - loss: 4.9152
# Epoch 12/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.1654 - loss: 4.8136
# Epoch 13/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.1643 - loss: 4.7290
# Epoch 14/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 29s 53ms/step - accuracy: 0.1678 - loss: 4.6728
# Epoch 15/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.1734 - loss: 4.5528
# Epoch 16/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.1768 - loss: 4.4716
# Epoch 17/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.1787 - loss: 4.3773
# Epoch 18/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - accuracy: 0.1911 - loss: 4.2767
# Epoch 19/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 29s 53ms/step - accuracy: 0.1977 - loss: 4.1704
# Epoch 20/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.1982 - loss: 4.1126
# Epoch 21/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 29s 53ms/step - accuracy: 0.2100 - loss: 3.9971
# Epoch 22/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.2143 - loss: 3.9222
# Epoch 23/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.2272 - loss: 3.8239
# Epoch 24/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 32s 58ms/step - accuracy: 0.2370 - loss: 3.7437
# Epoch 25/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.2356 - loss: 3.7180
# Epoch 26/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 32s 57ms/step - accuracy: 0.2681 - loss: 3.5557
# Epoch 27/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.2700 - loss: 3.5338
# Epoch 28/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - accuracy: 0.2879 - loss: 3.4226
# Epoch 29/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.3042 - loss: 3.3377
# Epoch 30/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.3221 - loss: 3.2480
# Epoch 31/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.3334 - loss: 3.1612
# Epoch 32/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - accuracy: 0.3479 - loss: 3.1122
# Epoch 33/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.3555 - loss: 3.0451
# Epoch 34/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.3648 - loss: 2.9880
# Epoch 35/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.3868 - loss: 2.8881
# Epoch 36/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.3948 - loss: 2.8289
# Epoch 37/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.4142 - loss: 2.7599
# Epoch 38/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 29s 53ms/step - accuracy: 0.4300 - loss: 2.6896
# Epoch 39/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.4426 - loss: 2.6070
# Epoch 40/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.4448 - loss: 2.5811
# Epoch 41/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 39s 53ms/step - accuracy: 0.4663 - loss: 2.4997
# Epoch 42/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.4711 - loss: 2.4832
# Epoch 43/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - accuracy: 0.4897 - loss: 2.3944
# Epoch 44/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 46ms/step - accuracy: 0.5026 - loss: 2.3259
# Epoch 45/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.5140 - loss: 2.2821
# Epoch 46/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 35s 63ms/step - accuracy: 0.5221 - loss: 2.2484
# Epoch 47/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 35s 64ms/step - accuracy: 0.5322 - loss: 2.1946
# Epoch 48/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - accuracy: 0.5442 - loss: 2.1598
# Epoch 49/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.5513 - loss: 2.1004
# Epoch 50/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 32s 59ms/step - accuracy: 0.5590 - loss: 2.0587
# Epoch 51/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.5710 - loss: 1.9963
# Epoch 52/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.5845 - loss: 1.9426
# Epoch 53/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 32s 58ms/step - accuracy: 0.5903 - loss: 1.9340
# Epoch 54/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.6021 - loss: 1.8681
# Epoch 55/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.6065 - loss: 1.8413
# Epoch 56/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.6188 - loss: 1.7947
# Epoch 57/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 54s 72ms/step - accuracy: 0.6287 - loss: 1.7517
# Epoch 58/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 34s 61ms/step - accuracy: 0.6338 - loss: 1.7172
# Epoch 59/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 32s 58ms/step - accuracy: 0.6427 - loss: 1.6791
# Epoch 60/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 32s 58ms/step - accuracy: 0.6516 - loss: 1.6358
# Epoch 61/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - accuracy: 0.6612 - loss: 1.6054
# Epoch 62/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 55ms/step - accuracy: 0.6655 - loss: 1.5883
# Epoch 63/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 39s 52ms/step - accuracy: 0.6752 - loss: 1.5460
# Epoch 64/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.6857 - loss: 1.4980
# Epoch 65/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 48ms/step - accuracy: 0.6922 - loss: 1.4700
# Epoch 66/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 48ms/step - accuracy: 0.6968 - loss: 1.4299
# Epoch 67/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7070 - loss: 1.4060
# Epoch 68/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.7139 - loss: 1.3606
# Epoch 69/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7165 - loss: 1.3464
# Epoch 70/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7192 - loss: 1.3202
# Epoch 71/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7314 - loss: 1.2870
# Epoch 72/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7347 - loss: 1.2721
# Epoch 73/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7479 - loss: 1.2137
# Epoch 74/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7458 - loss: 1.2278
# Epoch 75/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7456 - loss: 1.1971
# Epoch 76/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - accuracy: 0.7526 - loss: 1.1788
# Epoch 77/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 48ms/step - accuracy: 0.7562 - loss: 1.1598
# Epoch 78/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7673 - loss: 1.1225
# Epoch 79/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7770 - loss: 1.0813
# Epoch 80/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.7747 - loss: 1.0746
# Epoch 81/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.7806 - loss: 1.0513
# Epoch 82/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - accuracy: 0.7779 - loss: 1.0594
# Epoch 83/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 28s 50ms/step - accuracy: 0.7842 - loss: 1.0263
# Epoch 84/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.7928 - loss: 0.9881
# Epoch 85/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.8002 - loss: 0.9640
# Epoch 86/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 41s 50ms/step - accuracy: 0.7948 - loss: 0.9727
# Epoch 87/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 28s 50ms/step - accuracy: 0.8045 - loss: 0.9439
# Epoch 88/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 28s 51ms/step - accuracy: 0.8010 - loss: 0.9361
# Epoch 89/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.8147 - loss: 0.8916
# Epoch 90/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 28s 51ms/step - accuracy: 0.8067 - loss: 0.9159
# Epoch 91/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.8123 - loss: 0.8982
# Epoch 92/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.8151 - loss: 0.8720
# Epoch 93/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.8182 - loss: 0.8523
# Epoch 94/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.8247 - loss: 0.8355
# Epoch 95/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - accuracy: 0.8263 - loss: 0.8194
# Epoch 96/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - accuracy: 0.8287 - loss: 0.8008
# Epoch 97/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.8306 - loss: 0.7866
# Epoch 98/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.8275 - loss: 0.7977
# Epoch 99/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.8294 - loss: 0.7910
# Epoch 100/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - accuracy: 0.8366 - loss: 0.7545

# %%
def generate_text(seed_text, next_words=10):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        
        output_word = next((word for word, index in tokenizer.word_index.items() if index == predicted), "")
        
        if output_word:
            seed_text = seed_text.strip() + " " + output_word
            
    return seed_text


print(generate_text("Blue sky"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Blue sky no pencil beauty’s truth to lay

# %%
print(generate_text("Roses are red"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Roses are red than thou art but for this back

# %%
print(generate_text("Paint it black"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Paint it black large woes new wail my dear time’s waste still thee

# %%
print(generate_text("Love is"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Love is my sin and thy dear virtue hate

# %%
print(generate_text("Blood"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Blood for nature’s eyes hath all his
